# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#Personal imports.
from pprint import pprint
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import Formatter

# %matplotlib inline

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#lits for holding the query information and to keep track of the records and sets.
record = 1
Set = 1
city_df = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxTemp = []
windSpeed = []

#Creates header of the data retrieval log. 
s = '-' * 30
print(f'Beginning Data Retrieval\n{s}')

#For each city in the list of randome cities .
for city in cities:
    
    #If the record is equal to 50 then reset record to 1 and add 1 to the set.
    if record == 50:
        Set += 1
        record = 1
    #if the record is less than 50 then try.
    try:
        #Query url for each city.
        query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=Imperial&q={city}"
        #Data in json format for each city.
        weather_data = requests.get(query_url).json()
        
        #Appends data to each of the empty lists created earlier.
        city_df.append(weather_data['name'])
        cloudiness.append(weather_data['clouds']['all'])
        country.append(weather_data['sys']['country'])
        date.append(pd.to_datetime(weather_data['dt'], unit = 's')) #Converts Unix data to datetime
        humidity.append(weather_data['main']['humidity'])
        lat.append(weather_data['coord']['lat'])
        lng.append(weather_data['coord']['lon'])
        maxTemp.append(weather_data['main']['temp_max'])
        windSpeed.append(weather_data['wind']['speed'])
        
        #Prints a log in the command line.
        print(f'Processing Record {record} of set {Set} | {city.title()}')
        
        #When eveything is done, adds a 1 to the record tally.
        record += 1
    
    #If data is not found for the desired city, then retur this message.
    except:
        print('City not found. Skipping...')
        
#End of the log.      
print(f'{s}\nData Retrieval Complete\n{s}')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of set 1 | Makakilo City
# Processing Record 2 of set 1 | Arraial Do Cabo
# Processing Record 3 of set 1 | Gat
# Processing Record 4 of set 1 | Pevek
# Processing Record 5 of set 1 | Wajima
# Processing Record 6 of set 1 | Saldanha
# Processing Record 7 of set 1 | Rikitea
# Processing Record 8 of set 1 | Ushuaia
# Processing Record 9 of set 1 | Bambous Virieux
# Processing Record 10 of set 1 | Grindavik
# Processing Record 11 of set 1 | Thompson
# Processing Record 12 of set 1 | Cape Town
# Processing Record 13 of set 1 | Bluff
# Processing Record 14 of set 1 | New Norfolk
# Processing Record 15 of set 1 | Beboto
# Processing Record 16 of set 1 | Yulara
# Processing Record 17 of set 1 | Barrow
# Processing Record 18 of set 1 | Palmer
# City not found. Skipping...
# Processing Record 19 of set 1 | Atuona
# Processing Record 20 of set 1 | Ukholovo
# Processing Record 21 of set 1 | Namibe
# Processing Record 22 of set 1 | Tasiilaq
# Processing Record 23 of set 1 | Sitka
# Processing Record 24 of set 1 | Busselton
# Processing Record 25 of set 1 | Hermanus
# Processing Record 26 of set 1 | Batemans Bay
# Processing Record 27 of set 1 | Hilo
# Processing Record 28 of set 1 | Aswan
# Processing Record 29 of set 1 | Lockhart
# Processing Record 30 of set 1 | Leningradskiy
# Processing Record 31 of set 1 | Albany
# Processing Record 32 of set 1 | Kuopio
# Processing Record 33 of set 1 | Laramie
# Processing Record 34 of set 1 | Port Elizabeth
# Processing Record 35 of set 1 | Tazovskiy
# Processing Record 36 of set 1 | Turukhansk
# Processing Record 37 of set 1 | Longyearbyen
# Processing Record 38 of set 1 | Mar Del Plata
# Processing Record 39 of set 1 | Esperance
# Processing Record 40 of set 1 | Mataura
# Processing Record 41 of set 1 | Jizan
# Processing Record 42 of set 1 | Bilma
# Processing Record 43 of set 1 | Vanavara
# Processing Record 44 of set 1 | Soc Trang
# Processing Record 45 of set 1 | Mahebourg
# Processing Record 46 of set 1 | Ranong
# Processing Record 47 of set 1 | Mirnyy
# Processing Record 48 of set 1 | Dryden
# Processing Record 49 of set 1 | Ponta Do Sol
# Processing Record 1 of set 2 | Jamestown
# Processing Record 2 of set 2 | Karratha
# Processing Record 3 of set 2 | Zhireken
# Processing Record 4 of set 2 | Port Lincoln
# Processing Record 5 of set 2 | Mezen
# Processing Record 6 of set 2 | Wanning
# Processing Record 7 of set 2 | Visakhapatnam
# Processing Record 8 of set 2 | Tiksi
# Processing Record 9 of set 2 | Laguna
# Processing Record 10 of set 2 | Hualmay
# Processing Record 11 of set 2 | Vardo
# Processing Record 12 of set 2 | San Ramon
# Processing Record 13 of set 2 | Ouesso
# Processing Record 14 of set 2 | Vila Franca Do Campo
# Processing Record 15 of set 2 | San Patricio
# Processing Record 16 of set 2 | Clyde River
# Processing Record 17 of set 2 | Alofi
# Processing Record 18 of set 2 | Labuhan
# Processing Record 19 of set 2 | Baker City
# Processing Record 20 of set 2 | Saskylakh
# Processing Record 21 of set 2 | Yellowknife
# Processing Record 22 of set 2 | Fershampenuaz
# Processing Record 23 of set 2 | Kapaa
# Processing Record 24 of set 2 | Punta Arenas
# Processing Record 25 of set 2 | Lebu
# Processing Record 26 of set 2 | Ilulissat
# Processing Record 27 of set 2 | Hobart
# Processing Record 28 of set 2 | Itarema
# Processing Record 29 of set 2 | Bredasdorp
# Processing Record 30 of set 2 | Abu Dhabi
# Processing Record 31 of set 2 | Yumen
# Processing Record 32 of set 2 | Palana
# Processing Record 33 of set 2 | Vaini
# Processing Record 34 of set 2 | Waingapu
# Processing Record 35 of set 2 | Kikwit
# Processing Record 36 of set 2 | Mugur-Aksy
# Processing Record 37 of set 2 | Chokurdakh
# Processing Record 38 of set 2 | Izumo
# Processing Record 39 of set 2 | Krasnyye Chetai
# Processing Record 40 of set 2 | Katsuura
# Processing Record 41 of set 2 | Latehar
# Processing Record 42 of set 2 | Geraldton
# Processing Record 43 of set 2 | Victoria
# Processing Record 44 of set 2 | Salym
# Processing Record 45 of set 2 | Muros
# Processing Record 46 of set 2 | Dikson
# Processing Record 47 of set 2 | Mayya
# Processing Record 48 of set 2 | Saint-Pierre
# Processing Record 49 of set 2 | Moose Factory
# Processing Record 1 of set 3 | Hithadhoo
# Processing Record 2 of set 3 | Serebryansk
# Processing Record 3 of set 3 | Butaritari
# Processing Record 4 of set 3 | Pacific Grove
# Processing Record 5 of set 3 | Bulaevo
# City not found. Skipping...
# Processing Record 6 of set 3 | Kuching
# Processing Record 7 of set 3 | Kampong Chhnang
# Processing Record 8 of set 3 | Taltal
# Processing Record 9 of set 3 | Ahipara
# Processing Record 10 of set 3 | Hornepayne
# Processing Record 11 of set 3 | Upata
# Processing Record 12 of set 3 | Nuuk
# Processing Record 13 of set 3 | Saint-Augustin
# Processing Record 14 of set 3 | Zunyi
# Processing Record 15 of set 3 | Kiama
# Processing Record 16 of set 3 | Palauig
# Processing Record 17 of set 3 | Rocha
# Processing Record 18 of set 3 | Faanui
# Processing Record 19 of set 3 | Henties Bay
# City not found. Skipping...
# Processing Record 20 of set 3 | Georgetown
# Processing Record 21 of set 3 | Iralaya
# Processing Record 22 of set 3 | Sistranda
# Processing Record 23 of set 3 | Bambanglipuro
# City not found. Skipping...
# Processing Record 24 of set 3 | Dong Hoi
# Processing Record 25 of set 3 | Birjand
# Processing Record 26 of set 3 | Saint George
# Processing Record 27 of set 3 | Myshkin
# Processing Record 28 of set 3 | Kihei
# Processing Record 29 of set 3 | Nikolskoye
# Processing Record 30 of set 3 | Shingu
# Processing Record 31 of set 3 | Castro
# Processing Record 32 of set 3 | Bethel
# Processing Record 33 of set 3 | East Moline
# Processing Record 34 of set 3 | Olinda
# Processing Record 35 of set 3 | Isangel
# Processing Record 36 of set 3 | Juba
# Processing Record 37 of set 3 | Cap Malheureux
# Processing Record 38 of set 3 | Lompoc
# Processing Record 39 of set 3 | Cherskiy
# Processing Record 40 of set 3 | Olafsvik
# Processing Record 41 of set 3 | Avarua
# Processing Record 42 of set 3 | Iwase
# Processing Record 43 of set 3 | Naze
# Processing Record 44 of set 3 | Araouane
# City not found. Skipping...
# Processing Record 45 of set 3 | East London
# Processing Record 46 of set 3 | Qaanaaq
# Processing Record 47 of set 3 | Altay
# Processing Record 48 of set 3 | Ust-Nera
# Processing Record 49 of set 3 | Taybad
# Processing Record 1 of set 4 | Maceio
# Processing Record 2 of set 4 | Ribeira Grande
# Processing Record 3 of set 4 | Allende
# Processing Record 4 of set 4 | Flin Flon
# Processing Record 5 of set 4 | Carnarvon
# Processing Record 6 of set 4 | Chicama
# Processing Record 7 of set 4 | Qeshm
# Processing Record 8 of set 4 | Arman
# Processing Record 9 of set 4 | Port Blair
# Processing Record 10 of set 4 | Talnakh
# Processing Record 11 of set 4 | Saint-Philippe
# Processing Record 12 of set 4 | Jambusar
# Processing Record 13 of set 4 | Kaitangata
# City not found. Skipping...
# Processing Record 14 of set 4 | Qasigiannguit
# City not found. Skipping...
# Processing Record 15 of set 4 | Ostrovnoy
# Processing Record 16 of set 4 | Mehamn
# City not found. Skipping...
# Processing Record 17 of set 4 | Georgiyevskoye
# Processing Record 18 of set 4 | Flinders
# Processing Record 19 of set 4 | Komsomolskiy
# Processing Record 20 of set 4 | Ambon
# Processing Record 21 of set 4 | College
# Processing Record 22 of set 4 | Kropotkin
# Processing Record 23 of set 4 | Azare
# Processing Record 24 of set 4 | Rudnogorsk
# Processing Record 25 of set 4 | Tolaga Bay
# Processing Record 26 of set 4 | Sao Filipe
# City not found. Skipping...
# Processing Record 27 of set 4 | Valparaiso
# City not found. Skipping...
# Processing Record 28 of set 4 | Iqaluit
# Processing Record 29 of set 4 | La Plata
# Processing Record 30 of set 4 | Atyrau
# Processing Record 31 of set 4 | Belchatow
# City not found. Skipping...
# Processing Record 32 of set 4 | Igede
# Processing Record 33 of set 4 | Slonim
# Processing Record 34 of set 4 | Balabac
# Processing Record 35 of set 4 | Touros
# Processing Record 36 of set 4 | Harper
# Processing Record 37 of set 4 | Cam Ranh
# Processing Record 38 of set 4 | Russell
# Processing Record 39 of set 4 | Cayenne
# Processing Record 40 of set 4 | Hovd
# Processing Record 41 of set 4 | Krasnokamensk
# Processing Record 42 of set 4 | Riyadh
# Processing Record 43 of set 4 | Peterhead
# Processing Record 44 of set 4 | Los Llanos De Aridane
# Processing Record 45 of set 4 | Ploemeur
# Processing Record 46 of set 4 | Caravelas
# Processing Record 47 of set 4 | Carroll
# Processing Record 48 of set 4 | Lobito
# Processing Record 49 of set 4 | Codrington
# Processing Record 1 of set 5 | Nanakuli
# Processing Record 2 of set 5 | Dingle
# Processing Record 3 of set 5 | Masyaf
# Processing Record 4 of set 5 | Khatanga
# Processing Record 5 of set 5 | Puerto Ayora
# Processing Record 6 of set 5 | Duluth
# Processing Record 7 of set 5 | Lashio
# Processing Record 8 of set 5 | Aklavik
# City not found. Skipping...
# Processing Record 9 of set 5 | Haines Junction
# Processing Record 10 of set 5 | Taitung
# Processing Record 11 of set 5 | Phan Thiet
# Processing Record 12 of set 5 | Kahului
# Processing Record 13 of set 5 | Olga
# Processing Record 14 of set 5 | Beisfjord
# Processing Record 15 of set 5 | Tarime
# Processing Record 16 of set 5 | Portland
# City not found. Skipping...
# Processing Record 17 of set 5 | Klaksvik
# Processing Record 18 of set 5 | Fuzhou
# Processing Record 19 of set 5 | Smithers
# Processing Record 20 of set 5 | Bathsheba
# Processing Record 21 of set 5 | Necochea
# Processing Record 22 of set 5 | Katobu
# Processing Record 23 of set 5 | Fare
# Processing Record 24 of set 5 | Port Alfred
# Processing Record 25 of set 5 | Puerto Leguizamo
# Processing Record 26 of set 5 | Vila Velha
# Processing Record 27 of set 5 | Lakatoro
# Processing Record 28 of set 5 | Batticaloa
# Processing Record 29 of set 5 | Vila Do Maio
# City not found. Skipping...
# Processing Record 30 of set 5 | Dong Xoai
# Processing Record 31 of set 5 | Donghai
# City not found. Skipping...
# Processing Record 32 of set 5 | Hay River
# Processing Record 33 of set 5 | Trofors
# Processing Record 34 of set 5 | Severo-Kurilsk
# Processing Record 35 of set 5 | Yangjiang
# Processing Record 36 of set 5 | Paamiut
# Processing Record 37 of set 5 | Luderitz
# Processing Record 38 of set 5 | Ussel
# Processing Record 39 of set 5 | Pimentel
# Processing Record 40 of set 5 | Bonthe
# Processing Record 41 of set 5 | Bhander
# Processing Record 42 of set 5 | Onega
# Processing Record 43 of set 5 | Provideniya
# City not found. Skipping...
# Processing Record 44 of set 5 | Gornyak
# Processing Record 45 of set 5 | Corinto
# Processing Record 46 of set 5 | Praya
# Processing Record 47 of set 5 | Airai
# City not found. Skipping...
# Processing Record 48 of set 5 | Deputatskiy
# Processing Record 49 of set 5 | Waipawa
# Processing Record 1 of set 6 | Asau
# Processing Record 2 of set 6 | Rincon
# Processing Record 3 of set 6 | Abu Samrah
# Processing Record 4 of set 6 | Parintins
# Processing Record 5 of set 6 | Takoradi
# Processing Record 6 of set 6 | Auki
# Processing Record 7 of set 6 | Hasaki
# Processing Record 8 of set 6 | Tucuman
# Processing Record 9 of set 6 | Hunucma
# Processing Record 10 of set 6 | Acapulco
# Processing Record 11 of set 6 | Kodiak
# Processing Record 12 of set 6 | Toamasina
# Processing Record 13 of set 6 | Vanimo
# Processing Record 14 of set 6 | Gushikawa
# Processing Record 15 of set 6 | Lopukhiv
# Processing Record 16 of set 6 | Beringovskiy
# City not found. Skipping...
# Processing Record 17 of set 6 | Sangar
# Processing Record 18 of set 6 | Paripiranga
# Processing Record 19 of set 6 | Chillicothe
# Processing Record 20 of set 6 | Rengo
# Processing Record 21 of set 6 | Moron
# Processing Record 22 of set 6 | Chumikan
# City not found. Skipping...
# Processing Record 23 of set 6 | Nenjiang
# Processing Record 24 of set 6 | Celestun
# Processing Record 25 of set 6 | Kidal
# Processing Record 26 of set 6 | Semnan
# Processing Record 27 of set 6 | Avera
# Processing Record 28 of set 6 | Lagoa
# Processing Record 29 of set 6 | Matay
# Processing Record 30 of set 6 | Tuatapere
# Processing Record 31 of set 6 | Sinnamary
# Processing Record 32 of set 6 | Xiashi
# Processing Record 33 of set 6 | Muisne
# Processing Record 34 of set 6 | Povenets
# Processing Record 35 of set 6 | Tikrit
# Processing Record 36 of set 6 | Yen Bai
# City not found. Skipping...
# Processing Record 37 of set 6 | Owando
# Processing Record 38 of set 6 | Cabo San Lucas
# Processing Record 39 of set 6 | Salisbury
# Processing Record 40 of set 6 | Tandil
# Processing Record 41 of set 6 | Caconda
# Processing Record 42 of set 6 | Goderich
# City not found. Skipping...
# Processing Record 43 of set 6 | Coahuayana
# Processing Record 44 of set 6 | Balakhninskiy
# Processing Record 45 of set 6 | Matamoros
# Processing Record 46 of set 6 | Ayan
# Processing Record 47 of set 6 | Marinette
# Processing Record 48 of set 6 | Mana
# Processing Record 49 of set 6 | Praia
# Processing Record 1 of set 7 | Sola
# Processing Record 2 of set 7 | San Policarpo
# Processing Record 3 of set 7 | Salalah
# Processing Record 4 of set 7 | Snezhnogorsk
# Processing Record 5 of set 7 | Chernyshevskiy
# Processing Record 6 of set 7 | Todos Santos
# Processing Record 7 of set 7 | Chapais
# Processing Record 8 of set 7 | Havre-Saint-Pierre
# Processing Record 9 of set 7 | Chornobayivka
# Processing Record 10 of set 7 | Sisimiut
# Processing Record 11 of set 7 | Hamilton
# Processing Record 12 of set 7 | Bouza
# City not found. Skipping...
# Processing Record 13 of set 7 | Lorengau
# Processing Record 14 of set 7 | Upernavik
# Processing Record 15 of set 7 | Ylivieska
# Processing Record 16 of set 7 | Kungurtug
# Processing Record 17 of set 7 | Kruisfontein
# Processing Record 18 of set 7 | Powell River
# Processing Record 19 of set 7 | San Francisco
# Processing Record 20 of set 7 | Santa Rosa
# Processing Record 21 of set 7 | San Rafael
# Processing Record 22 of set 7 | Pecos
# Processing Record 23 of set 7 | Pervomayskoye
# Processing Record 24 of set 7 | Korgen
# Processing Record 25 of set 7 | Buraydah
# Processing Record 26 of set 7 | Santiago De Chuco
# Processing Record 27 of set 7 | Balao
# Processing Record 28 of set 7 | Bartica
# Processing Record 29 of set 7 | Chapleau
# Processing Record 30 of set 7 | Rawson
# Processing Record 31 of set 7 | Mount Isa
# Processing Record 32 of set 7 | Kavieng
# Processing Record 33 of set 7 | Juegang
# Processing Record 34 of set 7 | Narsaq
# Processing Record 35 of set 7 | Bloemhof
# Processing Record 36 of set 7 | Byron Bay
# Processing Record 37 of set 7 | Torbay
# Processing Record 38 of set 7 | Matata
# Processing Record 39 of set 7 | Aden
# Processing Record 40 of set 7 | Bay Roberts
# Processing Record 41 of set 7 | Itoman
# Processing Record 42 of set 7 | Colares
# Processing Record 43 of set 7 | Kieta
# Processing Record 44 of set 7 | Kloulklubed
# Processing Record 45 of set 7 | Camocim
# Processing Record 46 of set 7 | Majene
# Processing Record 47 of set 7 | Saiha
# Processing Record 48 of set 7 | Sungurlu
# Processing Record 49 of set 7 | Belmonte
# Processing Record 1 of set 8 | Santa Fe
# Processing Record 2 of set 8 | Presidencia Roque Saenz Pena
# Processing Record 3 of set 8 | Fez
# Processing Record 4 of set 8 | Bastrop
# Processing Record 5 of set 8 | Te Anau
# Processing Record 6 of set 8 | Ruffano
# Processing Record 7 of set 8 | Awbari
# Processing Record 8 of set 8 | Mandalgovi
# Processing Record 9 of set 8 | Kodino
# Processing Record 10 of set 8 | Bengkulu
# Processing Record 11 of set 8 | Seymchan
# Processing Record 12 of set 8 | Mildura
# Processing Record 13 of set 8 | Luzhou
# Processing Record 14 of set 8 | Itacarambi
# Processing Record 15 of set 8 | Biharia
# Processing Record 16 of set 8 | Scarborough
# Processing Record 17 of set 8 | Bataipora
# Processing Record 18 of set 8 | Tual
# Processing Record 19 of set 8 | Kande
# Processing Record 20 of set 8 | Tura
# Processing Record 21 of set 8 | Tazmalt
# Processing Record 22 of set 8 | Port Hedland
# Processing Record 23 of set 8 | Winsum
# Processing Record 24 of set 8 | Rafaela
# Processing Record 25 of set 8 | Baykit
# Processing Record 26 of set 8 | Santa Cruz Do Capibaribe
# Processing Record 27 of set 8 | Husavik
# Processing Record 28 of set 8 | Chuy
# City not found. Skipping...
# Processing Record 29 of set 8 | Ughelli
# Processing Record 30 of set 8 | Alice Springs
# City not found. Skipping...
# Processing Record 31 of set 8 | Alberton
# Processing Record 32 of set 8 | Souillac
# Processing Record 33 of set 8 | Ovalle
# Processing Record 34 of set 8 | Parana
# Processing Record 35 of set 8 | North Myrtle Beach
# City not found. Skipping...
# Processing Record 36 of set 8 | Alamogordo
# Processing Record 37 of set 8 | Sergeyevka
# Processing Record 38 of set 8 | Lasa
# Processing Record 39 of set 8 | Harnosand
# Processing Record 40 of set 8 | Vestmannaeyjar
# Processing Record 41 of set 8 | Palu
# Processing Record 42 of set 8 | San Antonio
# Processing Record 43 of set 8 | Champasak
# Processing Record 44 of set 8 | Aykhal
# Processing Record 45 of set 8 | Viedma
# Processing Record 46 of set 8 | Petropavlovsk-Kamchatskiy
# Processing Record 47 of set 8 | Lieto
# Processing Record 48 of set 8 | Guerrero Negro
# Processing Record 49 of set 8 | Spokoynaya
# Processing Record 1 of set 9 | Yovon
# Processing Record 2 of set 9 | Bad Doberan
# Processing Record 3 of set 9 | Tuktoyaktuk
# Processing Record 4 of set 9 | Srednekolymsk
# Processing Record 5 of set 9 | Quatre Cocos
# Processing Record 6 of set 9 | Voh
# Processing Record 7 of set 9 | Abu Kamal
# Processing Record 8 of set 9 | Bara
# Processing Record 9 of set 9 | Villacarrillo
# Processing Record 10 of set 9 | Holguin
# Processing Record 11 of set 9 | Mahabad
# Processing Record 12 of set 9 | Tartagal
# Processing Record 13 of set 9 | Rorvik
# Processing Record 14 of set 9 | Kudahuvadhoo
# Processing Record 15 of set 9 | Malayal
# Processing Record 16 of set 9 | Adre
# Processing Record 17 of set 9 | Camacha
# Processing Record 18 of set 9 | La Ronge
# Processing Record 19 of set 9 | Liyang
# Processing Record 20 of set 9 | Goundi
# Processing Record 21 of set 9 | Okhotsk
# Processing Record 22 of set 9 | Dzhebariki-Khaya
# Processing Record 23 of set 9 | Aleksandrov Gay
# Processing Record 24 of set 9 | Saint-Georges
# Processing Record 25 of set 9 | Zimovniki
# Processing Record 26 of set 9 | Abaza
# Processing Record 27 of set 9 | Rio Grande
# Processing Record 28 of set 9 | Dalby
# Processing Record 29 of set 9 | Radford
# Processing Record 30 of set 9 | Fonte Boa
# Processing Record 31 of set 9 | Terrace Bay
# Processing Record 32 of set 9 | Ahuimanu
# Processing Record 33 of set 9 | Guane
# Processing Record 34 of set 9 | Nemuro
# Processing Record 35 of set 9 | Ourinhos
# Processing Record 36 of set 9 | Koygorodok
# Processing Record 37 of set 9 | Hofn
# Processing Record 38 of set 9 | Lucea
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of set 9 | Jakar
# Processing Record 40 of set 9 | Vicuna
# Processing Record 41 of set 9 | Astana
# City not found. Skipping...
# Processing Record 42 of set 9 | Khor
# Processing Record 43 of set 9 | Nipawin
# Processing Record 44 of set 9 | Lazarev
# Processing Record 45 of set 9 | Lapinig
# Processing Record 46 of set 9 | Dawson Creek
# Processing Record 47 of set 9 | Tabasalu
# Processing Record 48 of set 9 | Najran
# Processing Record 49 of set 9 | Jalu
# Processing Record 1 of set 10 | Maraba
# Processing Record 2 of set 10 | Sonoita
# Processing Record 3 of set 10 | Tambun
# Processing Record 4 of set 10 | Ambovombe
# Processing Record 5 of set 10 | Manono
# Processing Record 6 of set 10 | Kamaishi
# Processing Record 7 of set 10 | Svetlaya
# Processing Record 8 of set 10 | Marang
# Processing Record 9 of set 10 | Troitsko-Pechorsk
# Processing Record 10 of set 10 | Ulety
# Processing Record 11 of set 10 | Marhaura
# Processing Record 12 of set 10 | Honningsvag
# Processing Record 13 of set 10 | Johnstown
# Processing Record 14 of set 10 | Kuminskiy
# Processing Record 15 of set 10 | Qobustan
# Processing Record 16 of set 10 | Sidi Ali
# Processing Record 17 of set 10 | Porto Velho
# Processing Record 18 of set 10 | Pangnirtung
# Processing Record 19 of set 10 | Suruc
# Processing Record 20 of set 10 | Ukiah
# Processing Record 21 of set 10 | Havoysund
# Processing Record 22 of set 10 | Ust-Tsilma
# Processing Record 23 of set 10 | Altamirano
# Processing Record 24 of set 10 | Jumilla
# Processing Record 25 of set 10 | Arlit
# Processing Record 26 of set 10 | Lavrentiya
# City not found. Skipping...
# Processing Record 27 of set 10 | Berlevag
# Processing Record 28 of set 10 | Cidreira
# Processing Record 29 of set 10 | Susanville
# Processing Record 30 of set 10 | Vitim
# Processing Record 31 of set 10 | Corn Island
# Processing Record 32 of set 10 | Sembe
# Processing Record 33 of set 10 | Matagami
# Processing Record 34 of set 10 | Linhares
# Processing Record 35 of set 10 | Sibu
# Processing Record 36 of set 10 | San Cristobal
# Processing Record 37 of set 10 | Egvekinot
# Processing Record 38 of set 10 | Kibala
# Processing Record 39 of set 10 | Longjiang
# Processing Record 40 of set 10 | Portsmouth
# City not found. Skipping...
# Processing Record 41 of set 10 | Havre
# Processing Record 42 of set 10 | Kapit
# Processing Record 43 of set 10 | Malakal
# Processing Record 44 of set 10 | Carlsbad
# Processing Record 45 of set 10 | Ekhabi
# Processing Record 46 of set 10 | Port Shepstone
# Processing Record 47 of set 10 | Oytal
# Processing Record 48 of set 10 | Krasnogvardeyets
# Processing Record 49 of set 10 | Funchal
# Processing Record 1 of set 11 | Jabinyanah
# Processing Record 2 of set 11 | Point Pedro
# Processing Record 3 of set 11 | Barbastro
# Processing Record 4 of set 11 | Cururupu
# Processing Record 5 of set 11 | Vallenar
# Processing Record 6 of set 11 | Kalabo
# Processing Record 7 of set 11 | Saint Anthony
# Processing Record 8 of set 11 | Kushima
# Processing Record 9 of set 11 | Pemba
# Processing Record 10 of set 11 | Daru
# Processing Record 11 of set 11 | Kudamatsu
# Processing Record 12 of set 11 | Marsaxlokk
# Processing Record 13 of set 11 | Ciudad Bolivar
# Processing Record 14 of set 11 | Mecca
# Processing Record 15 of set 11 | Nchelenge
# Processing Record 16 of set 11 | Evensk
# Processing Record 17 of set 11 | Pavagada
# Processing Record 18 of set 11 | Bokoro
# Processing Record 19 of set 11 | Yamada
# Processing Record 20 of set 11 | Oktyabrskoye
# Processing Record 21 of set 11 | Lethem
# Processing Record 22 of set 11 | Verkhnetulomskiy
# Processing Record 23 of set 11 | Doha
# Processing Record 24 of set 11 | Qaqortoq
# Processing Record 25 of set 11 | Rio Gallegos
# Processing Record 26 of set 11 | Kachiry
# Processing Record 27 of set 11 | Kuito
# Processing Record 28 of set 11 | Pando
# Processing Record 29 of set 11 | Marshfield
# Processing Record 30 of set 11 | Yei
# City not found. Skipping...
# Processing Record 31 of set 11 | Tihuatlan
# Processing Record 32 of set 11 | Innisfail
# Processing Record 33 of set 11 | Camopi
# Processing Record 34 of set 11 | Samoded
# Processing Record 35 of set 11 | Grand Gaube
# Processing Record 36 of set 11 | Olbia
# Processing Record 37 of set 11 | Walvis Bay
# Processing Record 38 of set 11 | Kandrian
# Processing Record 39 of set 11 | Tucuru
# Processing Record 40 of set 11 | Norman Wells
# City not found. Skipping...
# Processing Record 41 of set 11 | Novouzensk
# Processing Record 42 of set 11 | Koryukivka
# Processing Record 43 of set 11 | Fort-Shevchenko
# Processing Record 44 of set 11 | Fianarantsoa
# Processing Record 45 of set 11 | Mareeba
# Processing Record 46 of set 11 | Fortuna
# Processing Record 47 of set 11 | Kishi
# Processing Record 48 of set 11 | Monte Santo
# Processing Record 49 of set 11 | Ampanihy
# Processing Record 1 of set 12 | Cabedelo
# Processing Record 2 of set 12 | Birao
# Processing Record 3 of set 12 | Emerald
# Processing Record 4 of set 12 | Porosozero
# Processing Record 5 of set 12 | Atasu
# Processing Record 6 of set 12 | Pangody
# Processing Record 7 of set 12 | Pauini
# Processing Record 8 of set 12 | Gasa
# Processing Record 9 of set 12 | Bangassou
# City not found. Skipping...
# Processing Record 10 of set 12 | Brest
# Processing Record 11 of set 12 | Boende
# Processing Record 12 of set 12 | Ishinomaki
# Processing Record 13 of set 12 | Gerash
# Processing Record 14 of set 12 | Mwinilunga
# Processing Record 15 of set 12 | Warrnambool
# Processing Record 16 of set 12 | Mansa
# Processing Record 17 of set 12 | Nova Borova
# Processing Record 18 of set 12 | Maxixe
# Processing Record 19 of set 12 | Elgin
# Processing Record 20 of set 12 | Faya
# Processing Record 21 of set 12 | Wakkanai
# Processing Record 22 of set 12 | Ancud
# Processing Record 23 of set 12 | Shache
# City not found. Skipping...
# Processing Record 24 of set 12 | Turayf
# Processing Record 25 of set 12 | Shahrud
# Processing Record 26 of set 12 | Zhigansk
# Processing Record 27 of set 12 | Linqing
# Processing Record 28 of set 12 | Constitucion
# Processing Record 29 of set 12 | Erenhot
# Processing Record 30 of set 12 | Libreville
# Processing Record 31 of set 12 | Mitu
# Processing Record 32 of set 12 | Xining
# Processing Record 33 of set 12 | Sibolga
# Processing Record 34 of set 12 | Maniitsoq
# Processing Record 35 of set 12 | Enshi
# Processing Record 36 of set 12 | Roald
# Processing Record 37 of set 12 | Ola
# Processing Record 38 of set 12 | Imbituba
# Processing Record 39 of set 12 | Listvyagi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of set 12 | Kampil
# Processing Record 41 of set 12 | Meulaboh
# Processing Record 42 of set 12 | Malinovskiy
# Processing Record 43 of set 12 | Biak
# Processing Record 44 of set 12 | Jiangkou
# Processing Record 45 of set 12 | Mount Gambier
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
#Dictionary to store all the lists.
city_dict = {
    'City' : city_df,
    'Cloudiness' : cloudiness,
    'Country' : country,
    'Date' : date,
    'Humidity' : humidity,
    'Lat' : lat,
    'Lng' : lng,
    'Max Temp' : maxTemp,
    'Wind Speed' : windSpeed
}

#Creates DataFrame from the dictionary.
weatherPy_df = pd.DataFrame(city_dict)

#Check for data type. 
weatherPy_df.dtypes
# Out:
# City                  object
# Cloudiness             int64
# Country               object
# Date          datetime64[ns]
# Humidity               int64
# Lat                  float64
# Lng                  float64
# Max Temp             float64
# Wind Speed           float64
# dtype: object

# %%
#Check for row total.
weatherPy_df.count()
# Out:
# City          584
# Cloudiness    584
# Country       584
# Date          584
# Humidity      584
# Lat           584
# Lng           584
# Max Temp      584
# Wind Speed    584
# dtype: int64

# %%
#Format datetime to show only year, month and day.
weatherPy_df['Date'] = weatherPy_df['Date'].dt.strftime('%d-%m-%Y')  

weatherPy_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Makakilo City           1      US  21-10-2020        70  21.35 -158.09
# 1  Arraial do Cabo           0      BR  21-10-2020        86 -22.97  -42.03
# 2       Kiryat Gat          12      IL  21-10-2020       100  31.61   34.76
# 3            Pevek          74      RU  21-10-2020        95  69.70  170.31
# 4           Wajima          20      JP  21-10-2020        52  37.40  136.90
#
#    Max Temp  Wind Speed
# 0     84.20        8.05
# 1     72.21       19.66
# 2     73.00        1.99
# 3     30.96       15.59
# 4     66.20        9.17

# %%
#Csv output.
weatherPy_df.to_csv('outputfile.csv', index = False)

# %%
#Takes the data of our query. 
date = weatherPy_df.loc[0,'Date']

#Creates a figure with 4 plots.
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize = (20,20))
fig.subplots_adjust(top=0.95) #Controls the space between the title and the figure.

#Title of the plot with the date.
fig.suptitle(f'Weather Analysis {date}', fontsize = 30)

#Plot 1
ax1.scatter(weatherPy_df['Lat'],
            weatherPy_df['Max Temp'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax1.set_ylabel('Max Temperature' , fontsize = 15)
ax1.set_xlabel('Latitude' , fontsize = 15)
ax1.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax1.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}F'.format(y))) #Formats y axis 
ax1.grid()

#Plot 2
ax2.scatter(weatherPy_df['Lat'],
            weatherPy_df['Humidity'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax2.set_ylabel('Humidity' , fontsize = 15)
ax2.set_xlabel('Latitude' , fontsize = 15)
ax2.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax2.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}%'.format(y))) #Formats y axis 
ax2.grid()

#Plot 3
ax3.scatter(weatherPy_df['Lat'],
            weatherPy_df['Cloudiness'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax3.set_ylabel('Cloudiness' , fontsize = 15)
ax3.set_xlabel('Latitude' , fontsize = 15)
ax3.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax3.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax3.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}%'.format(y))) #Formats y axis 
ax3.grid()

#Plot 4
ax4.scatter(weatherPy_df['Lat'],
            weatherPy_df['Wind Speed'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax4.set_ylabel('Wind Speed' , fontsize = 15)
ax4.set_xlabel('Latitude' , fontsize = 15)
ax4.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax4.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax4.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f} mph'.format(y))) #Formats y axis 
ax4.grid()

plt.show()

#Saves the plots.
fig.savefig("../output_data/latitudePLots.png")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = weatherPy_df[weatherPy_df["Lat"]>=0]
south_df = weatherPy_df[weatherPy_df["Lat"]<0]

#List of the paramters used to compare against latitude.
comparison = ['Max Temp', 'Humidity', 'Cloudiness','Wind Speed']

# %%
#Data distribution.
NorthernPct = len(north_df) / len(weatherPy_df) *100

NorthernPct
# Out:
# 71.57534246575342

# %%
#Data distribution.
SouthernPct = len(south_df) / len(weatherPy_df) * 100

SouthernPct
# Out:
# 28.424657534246577

# %%
#Date of the query.
date = weatherPy_df.loc[0,'Date']

#Creates a figure with 4 plots.
fig, axs = plt.subplots(4, 1, figsize=(40,30))
cols_level = [f'ax_{i}' for i in range(len(axs.flat))] #1-D iterator to iterate over the array axs.

#Title
fig.suptitle(f'Northern Hemisphere Weather Analysis {date}', fontsize = 30)
fig.subplots_adjust(top=0.95) #Controls the space between the title and the plots.

#For loop to create plots. 
for i, ax in enumerate(axs.flat):
    
    #Data for the x and y
    x_values = north_df['Lat']
    y_values = north_df[comparison[i]]
    
    #Linear regression formula.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    #Line equation text and correlation factor.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + "\nThe r-squared is: " + str(round(rvalue,4))

    #Scatter plot. 
    ax.scatter(x_values,
               y_values,
               facecolors = 'lightskyblue',
               edgecolors = 'black')

    #Line plot - by plotting points of x values long the regressvalues. 
    ax.plot(x_values,regress_values,"r-")
    ax.annotate(line_eq,
             (0,-8), #location of the line_eq
             fontsize = 15,
             color = "red")

    #label for x and y axis.
    ax.set_xlabel('Latitude',fontsize = 15)
    ax.set_ylabel(comparison[i],fontsize = 25)
     
    #lim of y
    ax.set_ylim(-10,north_df[comparison[i]].max()+5)
    
    #Creates grid for each plot.
    ax.grid()
    
    #Selects the format for y based on the plot.
    if comparison[i] == 'Max Temp':
        formatAxis = '{:.0f}F'
        
    elif comparison[i] == 'Wind Speed':
        formatAxis = '{:.0f} mph'
        
    else:
        formatAxis = '{:.0f}%'
    
    #Applies the format to the y axis.
    ax.set_yticklabels([formatAxis.format(int(x)) for x in ax.get_yticks().tolist()])
    
    #Controls the size of the x and y ticks.
    ax.tick_params(axis='y',
                which='major',
                labelsize = 20)
    ax.tick_params(axis='x',
                which='major',
                labelsize = 13)

plt.show()

#Saves the plot. 
fig.savefig("../output_data/NorthernPLots.png")

# %%
#Date
date = weatherPy_df.loc[0,'Date']

#Creates a figure with 4 plots.
fig, axs = plt.subplots(4, 1, figsize=(40,30))
cols_level = [f'ax_{i}' for i in range(len(axs.flat))]

#Title
fig.suptitle(f'Southern Hemisphere Weather Analysis {date}', fontsize = 30)
fig.subplots_adjust(top=0.95)

#For loop to create plots. 
for i, ax in enumerate(axs.flat):
    
     #Data for the x and y
    x_values = south_df['Lat']
    y_values = south_df[comparison[i]]
    
    #Linear regression formula.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    #Line equation text.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + "\nThe r-squared is: " + str(round(rvalue,4))

    #Scatter plot. 
    ax.scatter(x_values,
               y_values,
               facecolors = 'lightskyblue',
               edgecolors = 'black')

    #Line plot - by plotting points of x values long the regressvalues. 
    ax.plot(x_values,regress_values,"r-")
    ax.annotate(line_eq,
             (-50,-8),
             fontsize = 15,
             color = "red")
    #label for x and y axis.
    ax.set_xlabel('Latitude',fontsize = 15)
    ax.set_ylabel(comparison[i],fontsize = 25)
    
    #lim of y
    ax.set_ylim(-10,north_df[comparison[i]].max()+5)
    
    #Grid for each plot.
    ax.grid()
    
    #Selects the format for y based on the plot.
    if comparison[i] == 'Max Temp':
        formatAxis = '{:.0f}F'
        
    elif comparison[i] == 'Wind Speed':
        formatAxis = '{:.0f} mph'
        
    else:
        formatAxis = '{:.0f}%'
    
    #Applies the format to the y axis.
    ax.set_yticklabels([formatAxis.format(int(x)) for x in ax.get_yticks().tolist()])
    
    #Controls the size of the x and y ticks.
    ax.tick_params(axis='y',
                which='major',
                labelsize = 20)
    ax.tick_params(axis='x',
                which='major',
                labelsize = 13)

plt.show()

#Saves the plot.
fig.savefig("../output_data/SouthernPLots.png")
